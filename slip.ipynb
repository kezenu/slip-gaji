# %%
import pandas as pd

df = pd.read_excel('gaji_juli.xlsx')
df.fillna(0, inplace=True)
print(df)
# Out:
#               nik                lokasi      bulan status  \
# 0    2.171100e+15  Alkatra Staff Office 2025-07-01    K/2
# 1    3.523111e+15  Alkatra Staff Office 2025-07-01     TK
# 2    2.171103e+15  Alkatra Staff Office 2025-07-01    K/2
# 3    2.171113e+15  Alkatra Staff Office 2025-07-01    K/2
# 4    2.171102e+15  Alkatra Staff Office 2025-07-01    K/1
# ..            ...                   ...        ...    ...
# 151  0.000000e+00        SMOE Indonesia 2025-08-01    K/2
# 152  0.000000e+00        SMOE Indonesia 2025-08-01    K/2
# 153  0.000000e+00        SMOE Indonesia 2025-08-01    K/0
# 154  0.000000e+00        SMOE Indonesia 2025-08-01    K/2
# 155  0.000000e+00        SMOE Indonesia 2025-08-01     TK
#
#                         nama         basic  jabatan  tunjangan_bpjstk  \
# 0               ALFIAN RAZAQ  5.000000e+06  1000000         344500.00
# 1    DHIMAS NOVIANTO SUTEDJO  4.989600e+06        0              0.00
# ...

# %%
for i in range(len(df)):
    value = df.iloc[i]
    print(f"nama        : {df['nama']}")
# Out:
# nama        : 0                 ALFIAN RAZAQ
# 1      DHIMAS NOVIANTO SUTEDJO
# 2             EVRIGON TAMBUNAN
# 3              JOEL SIMATUPANG
# 4           MATIN AZIZ SAPUTRA
#                 ...
# 151                    SOPINGI
# 152      ADI MANGGALA MANURUNG
# 153          EKO SANDI SAPUTRO
# 154                JEKI HARIUS
# 155              RIDO ALMINATA
# Name: nama, Length: 156, dtype: object
# nama        : 0                 ALFIAN RAZAQ
# 1      DHIMAS NOVIANTO SUTEDJO
# 2             EVRIGON TAMBUNAN
# 3              JOEL SIMATUPANG
# 4           MATIN AZIZ SAPUTRA
#                 ...
# 151                    SOPINGI
# 152      ADI MANGGALA MANURUNG
# 153          EKO SANDI SAPUTRO
# 154                JEKI HARIUS
# 155              RIDO ALMINATA
# Name: nama, Length: 156, dtype: object
# nama        : 0                 ALFIAN RAZAQ
# 1      DHIMAS NOVIANTO SUTEDJO
# 2             EVRIGON TAMBUNAN
# 3              JOEL SIMATUPANG
# 4           MATIN AZIZ SAPUTRA
# ...
